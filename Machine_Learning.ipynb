# %% [markdown]
# # Projeto Analise de Dados com Machine Learning
# Nesse projeto vou utilizar base de dados "clientes.csv" para treinar a IA
#
# # Bibliotecas
# *  Pandas
# *  Sklearn
#
# # Dois modelos foram escolhidos para o projeto
#
# *  RandomForestClassifier
# *  KNeighborsClassifier
#
# # Com base no treino farei uma previsao para a base de dados "novos_clientes.csv"
#
# `Por padrao o colab ja vem com o Pndas e Sklearn instalados`

# %%
# importaçoes necessarias para o projeto
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Vamos ler nossa base de Dados e observar atentamente o tipo das colunas

# %%
clientes= pd.read_csv("/content/clientes.csv")
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id_cliente                100000 non-null  int64
#  1   mes                       100000 non-null  int64
#  2   idade                     100000 non-null  float64
#  3   profissao                 100000 non-null  object
#  4   salario_anual             100000 non-null  float64
#  5   num_contas                100000 non-null  float64
#  6   num_cartoes               100000 non-null  float64
#  7   juros_emprestimo          100000 non-null  float64
#  8   num_emprestimos           100000 non-null  float64
#  9   dias_atraso               100000 non-null  float64
#  10  num_pagamentos_atrasados  100000 non-null  float64
#  11  num_verificacoes_credito  100000 non-null  float64
#  12  mix_credito               100000 non-null  object
#  13  divida_total              100000 non-null  float64
#  14  taxa_uso_credito          100000 non-null  float64
#  15  idade_historico_credito   100000 non-null  float64
#  16  investimento_mensal       100000 non-null  float64
#  17  comportamento_pagamento   100000 non-null  object
#  18  saldo_final_mes           100000 non-null  float64
#  19  score_credito             100000 non-null  object
#  20  emprestimo_carro          100000 non-null  int64
#  21  emprestimo_casa           100000 non-null  int64
#  22  emprestimo_pessoal        100000 non-null  int64
#  23  emprestimo_credito        100000 non-null  int64
#  24  emprestimo_estudantil     100000 non-null  int64
# dtypes: float64(14), int64(7), object(4)
# memory usage: 19.1+ MB

# %% [markdown]
# # Para melhor analise vamos converter nossa base de dados em um DATAFRAME do Pandas

# %%
df_clientes= pd.DataFrame(clientes).reset_index()
display(df_clientes)
# Out:
#        index  id_cliente  mes  idade  profissao  salario_anual  num_contas  \
# 0          0        3392    1   23.0  cientista       19114.12         3.0
# 1          1        3392    2   23.0  cientista       19114.12         3.0
# 2          2        3392    3   23.0  cientista       19114.12         3.0
# 3          3        3392    4   23.0  cientista       19114.12         3.0
# 4          4        3392    5   23.0  cientista       19114.12         3.0
# ...      ...         ...  ...    ...        ...            ...         ...
# 99995  99995       37932    4   25.0   mecanico       39628.99         4.0
# 99996  99996       37932    5   25.0   mecanico       39628.99         4.0
# 99997  99997       37932    6   25.0   mecanico       39628.99         4.0
# 99998  99998       37932    7   25.0   mecanico       39628.99         4.0
# 99999  99999       37932    8   25.0   mecanico       39628.99         4.0
#
#        num_cartoes  juros_emprestimo  num_emprestimos  ...  \
# 0              4.0               3.0              4.0  ...
# 1              4.0               3.0              4.0  ...
# 2              4.0               3.0              4.0  ...
# 3              4.0               3.0              4.0  ...
# 4              4.0               3.0              4.0  ...
# ...            ...               ...              ...  ...
# 99995          6.0               7.0              2.0  ...
# 99996          6.0               7.0              2.0  ...
# 99997          6.0               7.0              2.0  ...
# 99998          6.0               7.0              2.0  ...
# 99999          6.0               7.0              2.0  ...
#
#        idade_historico_credito  investimento_mensal  \
# 0                        265.0            21.465380
# 1                        266.0            21.465380
# 2                        267.0            21.465380
# 3                        268.0            21.465380
# 4                        269.0            21.465380
# ...                        ...                  ...
# 99995                    378.0            24.028477
# 99996                    379.0            24.028477
# 99997                    380.0            24.028477
# 99998                    381.0            24.028477
# 99999                    382.0            24.028477
#
#            comportamento_pagamento saldo_final_mes  score_credito  \
# 0      alto_gasto_pagamento_baixos      312.494089           Good
# 1       baixo_gasto_pagamento_alto      284.629162           Good
# 2      baixo_gasto_pagamento_medio      331.209863           Good
# 3      baixo_gasto_pagamento_baixo      223.451310           Good
# 4       alto_gasto_pagamento_medio      341.489231           Good
# ...                            ...             ...            ...
# 99995    alto_gasto_pagamento_alto      479.866228           Poor
# 99996   alto_gasto_pagamento_medio      496.651610           Poor
# 99997    alto_gasto_pagamento_alto      516.809083           Poor
# 99998   baixo_gasto_pagamento_alto      319.164979       Standard
# 99999   alto_gasto_pagamento_medio      393.673696           Poor
#
#        emprestimo_carro  emprestimo_casa  emprestimo_pessoal  \
# 0                     1                1                   1
# 1                     1                1                   1
# 2                     1                1                   1
# 3                     1                1                   1
# 4                     1                1                   1
# ...                 ...              ...                 ...
# 99995                 1                0                   0
# 99996                 1                0                   0
# 99997                 1                0                   0
# 99998                 1                0                   0
# 99999                 1                0                   0
#
#       emprestimo_credito  emprestimo_estudantil
# 0                      1                      0
# 1                      1                      0
# 2                      1                      0
# 3                      1                      0
# 4                      1                      0
# ...                  ...                    ...
# 99995                  0                      1
# 99996                  0                      1
# 99997                  0                      1
# 99998                  0                      1
# 99999                  0                      1
#
# [100000 rows x 26 columns]

# %% [markdown]
# # Converter a coluna profissao para o tipo int()
#
# Para que para que o algoritimo funcione sao necessarios dados do tipo **numerico**

# %%
conversor1= LabelEncoder()
clientes["profissao"]= conversor1.fit_transform(clientes["profissao"])


conversor2= LabelEncoder()
clientes["mix_credito"]= conversor2.fit_transform(clientes["mix_credito"])

conversor3= LabelEncoder()
clientes["comportamento_pagamento"]= conversor3.fit_transform(clientes["comportamento_pagamento"])

display(clientes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id_cliente                100000 non-null  int64
#  1   mes                       100000 non-null  int64
#  2   idade                     100000 non-null  float64
#  3   profissao                 100000 non-null  int64
#  4   salario_anual             100000 non-null  float64
#  5   num_contas                100000 non-null  float64
#  6   num_cartoes               100000 non-null  float64
#  7   juros_emprestimo          100000 non-null  float64
#  8   num_emprestimos           100000 non-null  float64
#  9   dias_atraso               100000 non-null  float64
#  10  num_pagamentos_atrasados  100000 non-null  float64
#  11  num_verificacoes_credito  100000 non-null  float64
#  12  mix_credito               100000 non-null  int64
#  13  divida_total              100000 non-null  float64
#  14  taxa_uso_credito          100000 non-null  float64
#  15  idade_historico_credito   100000 non-null  float64
#  16  investimento_mensal       100000 non-null  float64
#  17  comportamento_pagamento   100000 non-null  int64
#  18  saldo_final_mes           100000 non-null  float64
#  19  score_credito             100000 non-null  object
#  20  emprestimo_carro          100000 non-null  int64
#  21  emprestimo_casa           100000 non-null  int64
#  22  emprestimo_pessoal        100000 non-null  int64
#  23  emprestimo_credito        100000 non-null  int64
#  24  emprestimo_estudantil     100000 non-null  int64
# dtypes: float64(14), int64(10), object(1)
# memory usage: 19.1+ MB
# None

# %% [markdown]
# # Separar as informaçoes da base para IA
#
# Separar em X e Y:
#
#
#
# *   **X** -> quem eu quero prever(coluna score_credito)
# *   **X** -> quem eu quero prever -> as outras colunas(todas as colunas que vou usar para fazer a previsao) estes dados necessitam ser numericos.

# %%
y= clientes["score_credito"]
x= clientes.drop(columns= ["score_credito", "id_cliente"])

# separando dados de treino e teste
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste= train_test_split(x, y, test_size= 0.3)

# %% [markdown]
# 1.  Criar modelo de IA -> prever nota de credito;
#
# 2.  Arvore de decisao -> RandomForest;
#
# 3.  Vizinhos Proximos -> KNN;

# %%
# importar o modelo
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# criar o modelo
modelo_arvoredecisao= RandomForestClassifier()
modelo_knn= KNeighborsClassifier()

# treinar o modelo
modelo_arvoredecisao.fit(x_treino, y_treino)
modelo_knn.fit(x_treino, y_treino)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# # Aqui faremos um Previsao usando os Modelos que treinamos anteriomente

# %%
# previsoes
previsao_arvore= modelo_arvoredecisao.predict(x_teste)
previsao_knn= modelo_knn.predict(x_teste)

# acuracia ou precisao
from sklearn.metrics import accuracy_score

# precisao do modelo arvore de decisao
display(accuracy_score(y_teste, previsao_arvore))

# precisao do modelo floresta (KNeighborsClassifier)
display(accuracy_score(y_teste, previsao_knn))
# Out:
# 0.8253
# 0.7371333333333333

# %% [markdown]
# # Descobrimos entao que o melhor modelo para nossa analise foi o Algoritimo de Arvore de Decisao.
#
# Vamos usa-lo em nossa tabela "novos_clientes"

# %%
# melhor modelo e arvore decisao
novos_clientes= pd.read_csv("/content/novos_clientes.csv")
# display(novos_clientes.info())


# converter a coluna profissao para o tipo int()
# lembrando que para que o algoritimo funcione sao necessarios dados do tipo numerico

conversor1= LabelEncoder()
novos_clientes["profissao"]= conversor1.fit_transform(novos_clientes["profissao"])


conversor2= LabelEncoder()
novos_clientes["mix_credito"]= conversor2.fit_transform(novos_clientes["mix_credito"])

conversor3= LabelEncoder()
novos_clientes["comportamento_pagamento"]= conversor3.fit_transform(novos_clientes["comportamento_pagamento"])

previsao= modelo_arvoredecisao.predict(novos_clientes)

novos_clientes["score_credito"]= previsao

display(previsao)
# Out:
# array(['Poor', 'Good', 'Standard'], dtype=object)

# %% [markdown]
# # Como resultado, nossa IA retornou uma lista do tipo object, onde cada indice representa o resultado da analise para cada cliente.
# Lembrando que nosso trabalho era avaliar o score de cada cliente em nossa base de Dados
#
# Resultados:
#
# **'Poor' == 'Ruim'**
#
# **'Good' == 'Bom'**
#
# **'Standard' == 'Regular'**
#
#
# `Com esses resultados podemos configurar nosso Modelo de IA para analisarmos outras bases de dados`
